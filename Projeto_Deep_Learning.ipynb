# %% [markdown]
# # Bruno Kadooka
# #Erick Alen
# #Leonardo Rodrigues
#
# #Trabalho de Deep Learning: CNN pré-treinada -> transfer learning
#
# #Objetivo - Realizar a classificação das 3 classes com maior eficácia possível

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras import layers
import os
import pandas as pd
import seaborn as sn

IMG_SIZE = 68

# %%
x = 1
for i = 1:
# Out:
# 2

# %%
#separação  dos datasets de treino, teste e validação
train_ds = tf.keras.utils.image_dataset_from_directory(
    'Downloads/archive/afhq/train',
    validation_split=0.2,
    subset="training",
    label_mode='categorical',
    seed=123,
    shuffle=True,
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=32)

val_ds = tf.keras.utils.image_dataset_from_directory(
  'Downloads/archive/afhq/train',
  validation_split=0.2,
  subset="validation",
  label_mode='categorical',
  seed=123,
  shuffle=True,
  image_size=(IMG_SIZE, IMG_SIZE),
  batch_size=32)

test_ds = tf.keras.utils.image_dataset_from_directory(
  'Downloads/archive/afhq/val',
  label_mode='categorical',
  shuffle=False,
  image_size=(IMG_SIZE, IMG_SIZE),
  batch_size=32)

class_names = train_ds.class_names
val_samples   = len(val_ds.file_paths)
train_samples = len(train_ds.file_paths)
test_samples  = len(test_ds.file_paths)
# Out:
# Found 14630 files belonging to 3 classes.
# Using 11704 files for training.
# Found 14630 files belonging to 3 classes.
# Using 2926 files for validation.
# Found 1500 files belonging to 3 classes.

# %%
#ex5 EfficientNetB0 por que era leve e tinha uma boa relação tempo por step x acuracia
base_model = tf.keras.applications.EfficientNetB0(weights='imagenet',
                                             include_top=False,
                                             input_shape=(IMG_SIZE,IMG_SIZE,3),
                                             pooling="avg")

train_ds = tf.keras.applications.efficientnet.preprocess_input(train_ds)
val_ds   = tf.keras.applications.efficientnet.preprocess_input(val_ds)
test_ds = tf.keras.applications.efficientnet.preprocess_input(test_ds)

x=base_model.output
x=tf.keras.layers.Dropout(0.5)(x)
preds=tf.keras.layers.Dense(3, activation='softmax')(x)  #ex 4
model = tf.keras.models.Model(
    inputs=base_model.input,
    outputs=preds
)

for l in model.layers:
  if l.name.split('_')[0] != 'dense':
    l.trainable=False
  else:
    l.trainable=True

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 68, 68, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 68, 68, 3)    0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 68, 68, 3)    7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 68, 68, 3)    0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 69, 69, 3)    0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 34, 34, 32)   864         ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 34, 34, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 34, 34, 32)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 34, 34, 32)  288         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 34, 34, 32)  128         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 34, 34, 32)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 34, 34, 32)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 34, 34, 16)   512         ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 34, 34, 16)  64          ['block1a_project_conv[0][0]']
#  lization)
#
#  block2a_expand_conv (Conv2D)   (None, 34, 34, 96)   1536        ['block1a_project_bn[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 34, 34, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 34, 34, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 35, 35, 96)  0           ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 17, 17, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 17, 17, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 17, 17, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 17, 17, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 17, 17, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 17, 17, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 17, 17, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 17, 17, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 17, 17, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 17, 17, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 17, 17, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 17, 17, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 17, 17, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 17, 17, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 17, 17, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 17, 17, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 17, 17, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 17, 17, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 17, 17, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 17, 17, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 21, 21, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 9, 9, 144)   3600        ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None,
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy'])

step_size_train=-(-train_samples//32)
step_size_val = -(-val_samples//32)

print("step_size_val=" + str(step_size_val) + " step_size_train="+ str(step_size_train))

#treinamento do modelo
history = model.fit(
    x=train_ds,
    steps_per_epoch=step_size_train,
    epochs=20,
    validation_data=val_ds,
    validation_steps=step_size_val)
# Out:
# step_size_val=92 step_size_train=366
# Epoch 1/20
# 366/366 [==============================] - 63s 158ms/step - loss: 0.2206 - accuracy: 0.9260 - val_loss: 0.0743 - val_accuracy: 0.9764
# Epoch 2/20
# 366/366 [==============================] - 56s 153ms/step - loss: 0.1041 - accuracy: 0.9643 - val_loss: 0.0581 - val_accuracy: 0.9815
# Epoch 3/20
# 366/366 [==============================] - 56s 154ms/step - loss: 0.0907 - accuracy: 0.9700 - val_loss: 0.0531 - val_accuracy: 0.9822
# Epoch 4/20
# 366/366 [==============================] - 57s 156ms/step - loss: 0.0867 - accuracy: 0.9700 - val_loss: 0.0505 - val_accuracy: 0.9836
# Epoch 5/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0794 - accuracy: 0.9727 - val_loss: 0.0469 - val_accuracy: 0.9846
# Epoch 6/20
# 366/366 [==============================] - 54s 148ms/step - loss: 0.0782 - accuracy: 0.9728 - val_loss: 0.0448 - val_accuracy: 0.9856
# Epoch 7/20
# 366/366 [==============================] - 54s 146ms/step - loss: 0.0743 - accuracy: 0.9723 - val_loss: 0.0440 - val_accuracy: 0.9860
# Epoch 8/20
# 366/366 [==============================] - 54s 147ms/step - loss: 0.0715 - accuracy: 0.9745 - val_loss: 0.0441 - val_accuracy: 0.9850
# Epoch 9/20
# 366/366 [==============================] - 54s 146ms/step - loss: 0.0724 - accuracy: 0.9756 - val_loss: 0.0440 - val_accuracy: 0.9863
# Epoch 10/20
# 366/366 [==============================] - 54s 146ms/step - loss: 0.0746 - accuracy: 0.9726 - val_loss: 0.0425 - val_accuracy: 0.9856
# Epoch 11/20
# 366/366 [==============================] - 53s 146ms/step - loss: 0.0707 - accuracy: 0.9734 - val_loss: 0.0465 - val_accuracy: 0.9833
# Epoch 12/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0690 - accuracy: 0.9747 - val_loss: 0.0443 - val_accuracy: 0.9846
# Epoch 13/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0699 - accuracy: 0.9740 - val_loss: 0.0437 - val_accuracy: 0.9853
# Epoch 14/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0678 - accuracy: 0.9761 - val_loss: 0.0428 - val_accuracy: 0.9850
# Epoch 15/20
# 366/366 [==============================] - 55s 149ms/step - loss: 0.0670 - accuracy: 0.9756 - val_loss: 0.0435 - val_accuracy: 0.9850
# Epoch 16/20
# 366/366 [==============================] - 55s 149ms/step - loss: 0.0682 - accuracy: 0.9770 - val_loss: 0.0427 - val_accuracy: 0.9856
# Epoch 17/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0665 - accuracy: 0.9763 - val_loss: 0.0419 - val_accuracy: 0.9850
# Epoch 18/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0691 - accuracy: 0.9767 - val_loss: 0.0412 - val_accuracy: 0.9860
# Epoch 19/20
# 366/366 [==============================] - 55s 150ms/step - loss: 0.0673 - accuracy: 0.9751 - val_loss: 0.0418 - val_accuracy: 0.9863
# Epoch 20/20
# 366/366 [==============================] - 55s 151ms/step - loss: 0.0679 - accuracy: 0.9756 - val_loss: 0.0430 - val_accuracy: 0.9856

# %%
results = model.evaluate(test_ds)
print('Acc: %.3f, Loss: %.3f' % (results[1], results[0]))
print(history.history.keys())
# Out:
# 47/47 [==============================] - 6s 124ms/step - loss: 0.0471 - accuracy: 0.9840
# Acc: 0.984, Loss: 0.047
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#ex11 - Learning rate
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()
print()
print()
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.show()

# %%
num_epochs      = len(history.history['val_loss'])
lr_value        = model.optimizer.get_config()['learning_rate']
base_model_name = base_model.name

final_name  = base_model_name + "_valSamples[" + str(val_samples) + "]"
final_name += "_train_sample[" + str(train_samples) + "]" + "_lr[" + str(lr_value).replace(".", "-") + "]" +"_num_epochs[" + str(num_epochs) + "]"

model.save(final_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: efficientnetb0_valSamples[3226]_train_sample[12904]_lr[0-001]_num_epochs[500]\assets
# INFO:tensorflow:Assets written to: efficientnetb0_valSamples[3226]_train_sample[12904]_lr[0-001]_num_epochs[500]\assets

# %% [markdown]
# > ![image.png](data:image/png;base64,...)

# %%
ytrue=[]
for images, label in test_ds:
    for e in label:
        ytrue.append(e.numpy()>0.5)


preds=model.predict(test_ds) # predict on the test data
ypred = (preds > 0.5)

classification = classification_report(ypred.argmax(axis=1),np.argmax(ytrue,axis=1))
print('----------------CLASSIFICATION--------------')
print(classification)
matrix = confusion_matrix(ypred.argmax(axis=1),np.argmax(ytrue,axis=1))
df_cm = pd.DataFrame(matrix, index = [i for i in range(3)],
                  columns = [i for i in range(3)])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, linewidths=2.5)
# Out:
# 47/47 [==============================] - 7s 121ms/step
# ----------------CLASSIFICATION--------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       499
#            1       0.99      0.99      0.99       498
#            2       0.98      0.98      0.98       503
#
#     accuracy                           0.98      1500
#    macro avg       0.98      0.98      0.98      1500
# weighted avg       0.98      0.98      0.98      1500
# <AxesSubplot:>

# %%
img = tf.keras.utils.load_img(
    'Downloads/test/1_rIkmavUeqyRySwlQdA9kKg.jpg', target_size=(IMG_SIZE,IMG_SIZE))

img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
plt.imshow(img)
plt.title(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# 1/1 [==============================] - 1s 1s/step
# Text(0.5, 1.0, 'This image most likely belongs to dog with a 57.43 percent confidence.')
